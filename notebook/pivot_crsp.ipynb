# %%
import pandas as pd
crsp = pd.read_csv('../data/CRSP_cleaned.csv')
# Out:
# /usr/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (6,9,16,20,22,56) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
return_table = pd.pivot_table(crsp, values='RET', index='date', columns='ticker_occurance')
return_table
# Out:
# ticker_occurance    AABA_4     AAL_2  AAN_1     AAN_2    AAPL_1  AAPL_2  \
# date
# 2005-01-03             NaN       NaN    NaN       NaN -0.017236     NaN
# 2005-01-04             NaN       NaN    NaN       NaN  0.010270     NaN
# 2005-01-05             NaN       NaN    NaN       NaN  0.008758     NaN
# 2005-01-06             NaN       NaN    NaN       NaN  0.000775     NaN
# 2005-01-07             NaN       NaN    NaN       NaN  0.072812     NaN
# 2005-01-10             NaN       NaN    NaN       NaN -0.004188     NaN
# 2005-01-11             NaN       NaN    NaN       NaN -0.063805     NaN
# 2005-01-12             NaN       NaN    NaN       NaN  0.013941     NaN
# 2005-01-13             NaN       NaN    NaN       NaN  0.066300     NaN
# 2005-01-14             NaN       NaN    NaN       NaN  0.005731     NaN
# 2005-01-18             NaN       NaN    NaN       NaN  0.006410     NaN
# 2005-01-19             NaN       NaN    NaN       NaN -0.010899     NaN
# ...

# %%
return_table.to_csv('../data/return_table.csv')
